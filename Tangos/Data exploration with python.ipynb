# %% [markdown]
# Interactive analysis with python
# --------------------------------
#
# Before starting this tutorial, ensure that you have set up _tangos_ [as described here](https://pynbody.github.io/tangos/) and the data sources [as described here](https://pynbody.github.io/tangos/data_exploration.html).
#
# We get started by importing the modules we'll need:

# %%
import os
os.chdir('/home/selvani/MAP/pynbody/Tangos')
import pynbody.test_utils
pynbody.test_utils.precache_test_data()

# %%
import multiprocessing, psutil

n_threads = multiprocessing.cpu_count()
n_cpus = psutil.cpu_count(logical=False)
print("Number of threads:", n_threads)
print("Number of physical CPUs:", n_cpus)
# Out:
# Number of threads: 72
# Number of physical CPUs: 36

# %%
import subprocess
import multiprocessing

def run_tangos_command(tangos_args, multi=True, num_threads=None):
    """
    Runs a tangos command with --backend multiprocessing-<N> where N is the number of CPU threads.

    Parameters:
        tangos_args (list): List of tangos command arguments, excluding the backend flag.

    Returns:
        int: Exit code of the process
    """
    if num_threads is None:
        num_threads = multiprocessing.cpu_count()
    if multi:
        backend_flag = f"multiprocessing-{num_threads}"
    else:
        backend_flag = "serial"

    command = ["tangos"] + tangos_args + ["--backend", backend_flag]

    print(f"Running: {' '.join(command)}")

    process = subprocess.Popen(command, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True)

    for line in process.stdout:
        print(line, end="")

    process.wait()
    return process.returncode

def run_tangos_mpi(tangos_args, num_processes=None):
    """
    Runs a tangos command via mpirun with --backend=mpi4py.

    Parameters:
        tangos_args (list): List of tangos command arguments (excluding the backend flag).
        num_processes (int, optional): Number of MPI processes to use. If None, uses all CPU threads.

    Returns:
        int: Exit code of the process.
    """
    if num_processes is None:
        num_processes = multiprocessing.cpu_count()

    command = ["mpirun", "-np", str(num_processes), "tangos"] + tangos_args + ["--backend", "mpi4py"]

    print(f"Running: {' '.join(command)}")

    process = subprocess.Popen(command, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True)

    for line in process.stdout:
        print(line, end="")

    process.wait()
    return process.returncode

def tokenize_command(command_str):
    """
    Tokenizes a tangos command string using simple space splitting.
    Removes leading 'tangos' if present.

    Parameters:
        command_str (str): The full tangos command string

    Returns:
        list[str]: List of tokens
    """
    tokens = command_str.strip().split(' ')
    if tokens and tokens[0] == "tangos":
        tokens = tokens[1:]
    return tokens

# %%
import os
os.environ['TANGOS_SIMULATION_FOLDER'] = '/home/selvani/MAP/pynbody/Tangos/'
os.environ['TANGOS_DB_CONNECTION'] = '/home/selvani/MAP/pynbody/Tangos/tangos_changa.db'

import tangos

# %%
tangos.init_db("tangos_changa.db")

# %%
# command = "tangos add tutorial_changa"
# tokens = tokenize_command(command)
# exit_code = run_tangos_command(tokens, multi=True, num_threads=36)

# !tangos add tutorial_changa
# Out:
# 2025-06-25 11:38:00,357 : Simulation already exists 'tutorial_changa'
# 2025-06-25 11:38:00,361 : Enumerate timestep extensions base='/home/selvani/MAP/pynbody/Tangos/tutorial_changa' patterns=['*.00???', '*.00????', '*.0????']
# 2025-06-25 11:38:00,365 : Found 5 candidates to be inspected
# 2025-06-25 11:38:09,927 : Param file is /home/selvani/MAP/pynbody/Tangos/tutorial_changa/pioneer50h128.1536gst1.bwK1.param
# 2025-06-25 11:38:09,928 : Log file is /home/selvani/MAP/pynbody/Tangos/tutorial_changa/pioneer50h128.1536gst1.bwK1.log
# 2025-06-25 11:38:09,949 : Add simulation property 'compiled'
# /home/selvani/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/tangos/core/creator.py:84: SAWarning: Object of type <SimulationProperty> not in session, add operation along 'Simulation.properties' will not proceed
#   default_session.commit()
# 2025-06-25 11:38:10,019 : Add simulation property 'macros'
# 2025-06-25 11:38:10,048 : Add simulation property 'dPhysDenMin'
# 2025-06-25 11:38:10,077 : Add simulation property 'dCStar'
# 2025-06-25 11:38:10,109 : Add simulation property 'dTempMax'
# 2025-06-25 11:38:10,149 : Add simulation property 'dESN'
# 2025-06-25 11:38:10,190 : Add simulation property 'bLowTCool'
# 2025-06-25 11:38:10,225 : Add simulation property 'bSelfShield'
# 2025-06-25 11:38:10,271 : Add simulation property 'dHubble0'
# 2025-06-25 11:38:10,317 : Add simulation property 'dOmega0'
# 2025-06-25 11:38:10,360 : Add simulation property 'dLambda'
# 2025-06-25 11:38:10,418 : Add simulation property 'dMsolUnit'
# 2025-06-25 11:38:10,467 : Add simulation property 'dKpcUnit'
# 2025-06-25 11:38:10,524 : Add simulation property 'approx_resolution_kpc'
# 2025-06-25 11:38:10,582 : Add simulation property 'approx_resolution_Msol'
# 2025-06-25 11:38:10,646 : Update simulation property 'handler'
# 2025-06-25 11:38:10,662 : Enumerate timestep extensions base='/home/selvani/MAP/pynbody/Tangos/tutorial_changa' patterns=['*.00???', '*.00????', '*.0????']
# 2025-06-25 11:38:10,665 : Found 5 candidates to be inspected
# 2025-06-25 11:38:11,253 : Add timestep 'pioneer50h128.1536gst1.bwK1.000384' to simulation 'tutorial_changa'
# 2025-06-25 11:38:11,318 : Reading halos for timestep 'pioneer50h128.1536gst1.bwK1.000384' using a stat file
# 2025-06-25 11:38:11,404 : Reading halos for timestep 'pioneer50h128.1536gst1.bwK1.000384' using a stat file
# 2025-06-25 11:38:11,513 : Add 365 Halos to timestep <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000384' z=4.57 t=1.31 Gyr>
# 2025-06-25 11:38:11,589 : No group statistics file found for timestep 'pioneer50h128.1536gst1.bwK1.000384'
# 2025-06-25 11:38:11,712 : Unable to read groups using pynbody; assuming step has none
# 2025-06-25 11:38:11,712 : Add 0 Groups to timestep <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000384' z=4.57 t=1.31 Gyr>
# 2025-06-25 11:38:12,398 : Add timestep 'pioneer50h128.1536gst1.bwK1.000448' to simulation 'tutorial_changa'
# 2025-06-25 11:38:12,463 : Reading halos for timestep 'pioneer50h128.1536gst1.bwK1.000448' using a stat file
# 2025-06-25 11:38:12,560 : Reading halos for timestep 'pioneer50h128.1536gst1.bwK1.000448' using a stat file
# 2025-06-25 11:38:12,683 : Add 410 Halos to timestep <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000448' z=4.03 t=1.53 Gyr>
# 2025-06-25 11:38:12,755 : No group statistics file found for timestep 'pioneer50h128.1536gst1.bwK1.000448'
# 2025-06-25 11:38:12,804 : Unable to read groups using pynbody; assuming step has none
# 2025-06-25 11:38:12,804 : Add 0 Groups to timestep <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000448' z=4.03 t=1.53 Gyr>
# 2025-06-25 11:38:13,710 : Add timestep 'pioneer50h128.1536gst1.bwK1.000640' to simulation 'tutorial_changa'
# 2025-06-25 11:38:13,776 : Reading halos for timestep 'pioneer50h128.1536gst1.bwK1.000640' using a stat file
# 2025-06-25 11:38:13,896 : Reading halos for timestep 'pioneer50h128.1536gst1.bwK1.000640' using a stat file
# 2025-06-25 11:38:14,055 : Add 547 Halos to timestep <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000640' z=2.96 t=2.17 Gyr>
# 2025-06-25 11:38:14,189 : No group statistics file found for timestep 'pioneer50h128.1536gst1.bwK1.000640'
# 2025-06-25 11:38:14,299 : Unable to read groups using pynbody; assuming step has none
# 2025-06-25 11:38:14,299 : Add 0 Groups to timestep <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000640' z=2.96 t=2.17 Gyr>
# 2025-06-25 11:38:15,195 : Add timestep 'pioneer50h128.1536gst1.bwK1.000832' to simulation 'tutorial_changa'
# 2025-06-25 11:38:15,259 : Reading halos for timestep 'pioneer50h128.1536gst1.bwK1.000832' using a stat file
# 2025-06-25 11:38:15,385 : Reading halos for timestep 'pioneer50h128.1536gst1.bwK1.000832' using a stat file
# 2025-06-25 11:38:15,557 : Add 666 Halos to timestep <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000832' z=2.32 t=2.82 Gyr>
# 2025-06-25 11:38:15,730 : No group statistics file found for timestep 'pioneer50h128.1536gst1.bwK1.000832'
# 2025-06-25 11:38:15,781 : Unable to read groups using pynbody; assuming step has none
# 2025-06-25 11:38:15,781 : Add 0 Groups to timestep <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000832' z=2.32 t=2.82 Gyr>
# 2025-06-25 11:38:16,698 : Add timestep 'pioneer50h128.1536gst1.bwK1.000960' to simulation 'tutorial_changa'
# 2025-06-25 11:38:16,770 : Reading halos for timestep 'pioneer50h128.1536gst1.bwK1.000960' using a stat file
# 2025-06-25 11:38:16,906 : Reading halos for timestep 'pioneer50h128.1536gst1.bwK1.000960' using a stat file
# 2025-06-25 11:38:17,083 : Add 719 Halos to timestep <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000960' z=2.02 t=3.25 Gyr>
# 2025-06-25 11:38:17,263 : No group statistics file found for timestep 'pioneer50h128.1536gst1.bwK1.000960'
# 2025-06-25 11:38:17,314 : Unable to read groups using pynbody; assuming step has none
# 2025-06-25 11:38:17,314 : Add 0 Groups to timestep <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000960' z=2.02 t=3.25 Gyr>

# %%
# !tangos import-properties Mvir Rvir --for tutorial_changa
# Out:
# 2025-06-25 13:37:09,455 : Processing <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000384' z=4.57 t=1.31 Gyr>
# 2025-06-25 13:37:09,736 : Add 730 properties
# 2025-06-25 13:37:10,745 : Processing <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000448' z=4.03 t=1.53 Gyr>
# 2025-06-25 13:37:10,901 : Add 820 properties
# 2025-06-25 13:37:11,008 : Processing <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000640' z=2.96 t=2.17 Gyr>
# 2025-06-25 13:37:11,182 : Add 1094 properties
# 2025-06-25 13:37:11,309 : Processing <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000832' z=2.32 t=2.82 Gyr>
# 2025-06-25 13:37:11,514 : Add 1332 properties
# 2025-06-25 13:37:11,733 : Processing <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000960' z=2.02 t=3.25 Gyr>
# 2025-06-25 13:37:11,970 : Add 1438 properties

# %%
tangos.all_simulations()
# Out:
# [<Simulation("tutorial_changa")>]

# %%
tangos.get_simulation("tutorial_changa").timesteps
# Out:
# [<TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000384' z=4.57 t=1.31 Gyr>,
#  <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000448' z=4.03 t=1.53 Gyr>,
#  <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000640' z=2.96 t=2.17 Gyr>,
#  <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000832' z=2.32 t=2.82 Gyr>,
#  <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000960' z=2.02 t=3.25 Gyr>]

# %%
tangos.get_simulation("tutorial_changa").timesteps[3].halos[3]
# Out:
# <Halo 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000832/halo_4' | NDM=199525 Nstar=7531 Ngas=19920>

# %%
halo = tangos.get_halo("tutorial_changa/%960/halo_1")
halo.keys()
# Out:
# ['Mvir',
#  'Rvir',
#  'contamination_fraction',
#  'shrink_center',
#  'max_radius',
#  'dm_density_profile',
#  'dm_mass_profile',
#  'gas_density_profile',
#  'gas_mass_profile',
#  'star_density_profile',
#  'star_mass_profile',
#  'gas_map_sideon',
#  'uvi_image_sideon',
#  'gas_map_faceon',
#  'uvi_image_faceon',
#  'gas_map',
#  'uvi_image',
#  'Mvir',
#  'Rvir',
#  'ptcls_in_common',
#  'ptcls_in_common',
#  'ptcls_in_common',
#  'ptcls_in_common']

# %%
# !tangos link --for tutorial_changa
# Out:
# 2025-06-25 11:41:08,002 : generating pairs of timesteps
# 2025-06-25 11:41:08,019 : Linking <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000384' z=4.57 t=1.31 Gyr> and <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000448' z=4.03 t=1.53 Gyr>
# 2025-06-25 11:41:08,082 : Gathering halo information for <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000384' z=4.57 t=1.31 Gyr> and <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000448' z=4.03 t=1.53 Gyr>
# 2025-06-25 11:41:41,444 : Gathering links for <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000384' z=4.57 t=1.31 Gyr> and <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000448' z=4.03 t=1.53 Gyr>
# 2025-06-25 11:41:41,497 : 4811 link(s) could not be identified because the halo objects do not exist in the DB
# 2025-06-25 11:41:41,497 : Identified 408 links between <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000384' z=4.57 t=1.31 Gyr> and <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000448' z=4.03 t=1.53 Gyr>
# 2025-06-25 11:41:41,530 : 4638 link(s) could not be identified because the halo objects do not exist in the DB
# 2025-06-25 11:41:41,530 : Identified 387 links between <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000448' z=4.03 t=1.53 Gyr> and <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000384' z=4.57 t=1.31 Gyr>
# 2025-06-25 11:41:41,530 : Preparing to commit links for <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000384' z=4.57 t=1.31 Gyr> and <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000448' z=4.03 t=1.53 Gyr>
# 2025-06-25 11:41:43,393 : Finished committing total of 795 links for <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000384' z=4.57 t=1.31 Gyr> and <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000448' z=4.03 t=1.53 Gyr>
# 2025-06-25 11:41:43,404 : Linking <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000448' z=4.03 t=1.53 Gyr> and <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000640' z=2.96 t=2.17 Gyr>
# 2025-06-25 11:41:43,428 : Gathering halo information for <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000448' z=4.03 t=1.53 Gyr> and <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000640' z=2.96 t=2.17 Gyr>
# 2025-06-25 11:42:14,571 : Gathering links for <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000448' z=4.03 t=1.53 Gyr> and <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000640' z=2.96 t=2.17 Gyr>
# 2025-06-25 11:42:14,587 : 6338 link(s) could not be identified because the halo objects do not exist in the DB
# 2025-06-25 11:42:14,587 : Identified 485 links between <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000448' z=4.03 t=1.53 Gyr> and <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000640' z=2.96 t=2.17 Gyr>
# 2025-06-25 11:42:14,601 : 5798 link(s) could not be identified because the halo objects do not exist in the DB
# 2025-06-25 11:42:14,601 : Identified 430 links between <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000640' z=2.96 t=2.17 Gyr> and <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000448' z=4.03 t=1.53 Gyr>
# 2025-06-25 11:42:14,601 : Preparing to commit links for <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000448' z=4.03 t=1.53 Gyr> and <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000640' z=2.96 t=2.17 Gyr>
# 2025-06-25 11:42:16,735 : Finished committing total of 915 links for <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000448' z=4.03 t=1.53 Gyr> and <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000640' z=2.96 t=2.17 Gyr>
# 2025-06-25 11:42:16,749 : Linking <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000640' z=2.96 t=2.17 Gyr> and <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000832' z=2.32 t=2.82 Gyr>
# 2025-06-25 11:42:16,777 : Gathering halo information for <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000640' z=2.96 t=2.17 Gyr> and <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000832' z=2.32 t=2.82 Gyr>
# 2025-06-25 11:42:49,892 : Gathering links for <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000640' z=2.96 t=2.17 Gyr> and <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000832' z=2.32 t=2.82 Gyr>
# 2025-06-25 11:42:49,915 : 8358 link(s) could not be identified because the halo objects do not exist in the DB
# 2025-06-25 11:42:49,915 : Identified 653 links between <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000640' z=2.96 t=2.17 Gyr> and <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000832' z=2.32 t=2.82 Gyr>
# 2025-06-25 11:42:49,933 : 7730 link(s) could not be identified because the halo objects do not exist in the DB
# 2025-06-25 11:42:49,933 : Identified 570 links between <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000832' z=2.32 t=2.82 Gyr> and <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000640' z=2.96 t=2.17 Gyr>
# 2025-06-25 11:42:49,933 : Preparing to commit links for <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000640' z=2.96 t=2.17 Gyr> and <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000832' z=2.32 t=2.82 Gyr>
# 2025-06-25 11:42:52,502 : Finished committing total of 1223 links for <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000640' z=2.96 t=2.17 Gyr> and <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000832' z=2.32 t=2.82 Gyr>
# 2025-06-25 11:42:52,514 : Linking <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000832' z=2.32 t=2.82 Gyr> and <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000960' z=2.02 t=3.25 Gyr>
# 2025-06-25 11:42:52,537 : Gathering halo information for <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000832' z=2.32 t=2.82 Gyr> and <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000960' z=2.02 t=3.25 Gyr>
# 2025-06-25 11:43:27,552 : Gathering links for <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000832' z=2.32 t=2.82 Gyr> and <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000960' z=2.02 t=3.25 Gyr>
# 2025-06-25 11:43:27,578 : 9229 link(s) could not be identified because the halo objects do not exist in the DB
# 2025-06-25 11:43:27,578 : Identified 786 links between <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000832' z=2.32 t=2.82 Gyr> and <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000960' z=2.02 t=3.25 Gyr>
# 2025-06-25 11:43:27,603 : 8613 link(s) could not be identified because the halo objects do not exist in the DB
# 2025-06-25 11:43:27,603 : Identified 731 links between <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000960' z=2.02 t=3.25 Gyr> and <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000832' z=2.32 t=2.82 Gyr>
# 2025-06-25 11:43:27,603 : Preparing to commit links for <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000832' z=2.32 t=2.82 Gyr> and <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000960' z=2.02 t=3.25 Gyr>
# 2025-06-25 11:43:31,455 : Finished committing total of 1517 links for <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000832' z=2.32 t=2.82 Gyr> and <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000960' z=2.02 t=3.25 Gyr>

# %%
# !tangos write contamination_fraction --for tutorial_changa
# Out:
# 2025-06-25 11:45:02,823 : Processing <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000384' z=4.57 t=1.31 Gyr>
# 2025-06-25 11:45:04,582 : Successfully gathered existing properties; calculating halo properties now...
# 2025-06-25 11:45:04,582 :   365 halos to consider; 1 calculation routines for each of them, resulting in 1 properties per halo
# 2025-06-25 11:45:04,582 :   The property modules are:
# 2025-06-25 11:45:04,582 :     tangos.properties.pynbody.zoom.Contamination
# 2025-06-25 11:45:18,162 : Done with <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000384' z=4.57 t=1.31 Gyr>
# 2025-06-25 11:45:18,210 : Processing <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000448' z=4.03 t=1.53 Gyr>
# 2025-06-25 11:45:19,103 : Successfully gathered existing properties; calculating halo properties now...
# 2025-06-25 11:45:19,103 :   410 halos to consider; 1 calculation routines for each of them, resulting in 1 properties per halo
# 2025-06-25 11:45:19,103 :   The property modules are:
# 2025-06-25 11:45:19,104 :     tangos.properties.pynbody.zoom.Contamination
# 2025-06-25 11:45:33,499 : Done with <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000448' z=4.03 t=1.53 Gyr>
# 2025-06-25 11:45:33,547 : Processing <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000640' z=2.96 t=2.17 Gyr>
# 2025-06-25 11:45:34,735 : Successfully gathered existing properties; calculating halo properties now...
# 2025-06-25 11:45:34,736 :   547 halos to consider; 1 calculation routines for each of them, resulting in 1 properties per halo
# 2025-06-25 11:45:34,736 :   The property modules are:
# 2025-06-25 11:45:34,736 :     tangos.properties.pynbody.zoom.Contamination
# 2025-06-25 11:45:51,883 : Done with <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000640' z=2.96 t=2.17 Gyr>
# 2025-06-25 11:45:51,935 : Processing <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000832' z=2.32 t=2.82 Gyr>
# 2025-06-25 11:45:53,755 : Successfully gathered existing properties; calculating halo properties now...
# 2025-06-25 11:45:53,755 :   666 halos to consider; 1 calculation routines for each of them, resulting in 1 properties per halo
# 2025-06-25 11:45:53,755 :   The property modules are:
# 2025-06-25 11:45:53,755 :     tangos.properties.pynbody.zoom.Contamination
# 2025-06-25 11:46:12,984 : Done with <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000832' z=2.32 t=2.82 Gyr>
# 2025-06-25 11:46:13,040 : Processing <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000960' z=2.02 t=3.25 Gyr>
# 2025-06-25 11:46:15,106 : Successfully gathered existing properties; calculating halo properties now...
# 2025-06-25 11:46:15,106 :   719 halos to consider; 1 calculation routines for each of them, resulting in 1 properties per halo
# 2025-06-25 11:46:15,106 :   The property modules are:
# 2025-06-25 11:46:15,106 :     tangos.properties.pynbody.zoom.Contamination
# 2025-06-25 11:46:35,263 : Done with <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000960' z=2.02 t=3.25 Gyr>
# 2025-06-25 11:46:43,511 : PROPERTY CALCULATION SUMMARY
# 2025-06-25 11:46:43,511 :             Succeeded: 2707 property calculations
# 2025-06-25 11:46:43,512 :               Errored: 0 property calculations
# 2025-06-25 11:46:43,512 :   Errored during load: 0 property calculations
# 2025-06-25 11:46:43,512 :        Already exists: 0 property calculations
# 2025-06-25 11:46:43,512 : Missing pre-requisite: 0 property calculations
# 2025-06-25 11:46:43,512 :
# 2025-06-25 11:46:43,512 : CUMULATIVE RUNNING TIMES, summed over all processes, if applicable
# 2025-06-25 11:46:43,512 :         Contamination        47.9s | 100.0%
# 2025-06-25 11:46:43,512 :

# %%
# command = 'tangos write dm_density_profile gas_density_profile uvi_image SFR_histogram --with-prerequisites --include-only=\"contamination_fraction<0.01\" --include-only=\"NDM()>1000\" --for tutorial_changa'
# tokens = tokenize_command(command)
# exit_code = run_tangos_command(tokens, num_threads=36)

# !mpirun -np 37 tangos write dm_density_profile gas_density_profile uvi_image --with-prerequisites --include-only="NDM()>5000" --include-only="contamination_fraction<0.01" --for tutorial_changa --backend mpi4py --load-mode server-shared-mem
# Out:
# [  1] 2025-06-25 12:02:56,818 : Processing <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000384' z=4.57 t=1.31 Gyr>
# [  1] 2025-06-25 12:02:57,208 : Missing prerequisites - added class <class 'tangos.properties.pynbody.centring.CentreAndRadius'>
# [  1] 2025-06-25 12:02:57,209 :                         providing properties ('shrink_center', 'max_radius')
# [  1] 2025-06-25 12:02:57,809 : User-specified inclusion criterion excluded 300 of 365 halos
# [  1] 2025-06-25 12:03:08,828 : Successfully gathered existing properties; calculating halo properties now...
# [  1] 2025-06-25 12:03:08,829 :   65 halos to consider; 4 calculation routines for each of them, resulting in 14 properties per halo
# [  1] 2025-06-25 12:03:08,829 :   The property modules are:
# [  1] 2025-06-25 12:03:08,829 :     tangos.properties.pynbody.centring.CentreAndRadius
# [  1] 2025-06-25 12:03:08,829 :     tangos.properties.pynbody.profile.HaloDensityProfile
# [  1] 2025-06-25 12:03:08,829 :     tangos.properties.pynbody.profile.BaryonicHaloDensityProfile
# [  1] 2025-06-25 12:03:08,829 :     tangos.properties.pynbody.images.BaryonicImages
# [  0] 2025-06-25 12:03:09,169 : Pynbody server: loaded 'pioneer50h128.1536gst1.bwK1.000384'
# [  0] 2025-06-25 12:03:09,170 :                 (shared memory mode)
# [  0] 2025-06-25 12:03:09,377 : Generating a shared object catalogue for 'halo's
# [ 28] 2025-06-25 12:03:59,792 : Uncaught exception ValueError('Number of smoothing particles exceeds number of particles in tree') during property calculation <tangos.properties.pynbody.images.BaryonicImages object at 0x7f80e8515c10> applied to <Halo 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000384/halo_31' | NDM=12464 Nstar=30 Ngas=416>
# [ 28] 2025-06-25 12:03:59,796 : Traceback (most recent call last):
# [ 28] 2025-06-25 12:03:59,796 :   File "/home/selvani/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/tangos/tools/property_writer.py", line 421, in _get_property_value
# [ 28] 2025-06-25 12:03:59,796 :     result = property_calculator.calculate(snapshot_data, db_data)
# [ 28] 2025-06-25 12:03:59,796 :              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [ 28] 2025-06-25 12:03:59,796 :   File "/home/selvani/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/tangos/properties/pynbody/centring.py", line 97, in new_fn
# [ 28] 2025-06-25 12:03:59,797 :     return fn(self, halo, existing_properties)
# [ 28] 2025-06-25 12:03:59,797 :            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [ 28] 2025-06-25 12:03:59,797 :   File "/home/selvani/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/tangos/properties/pynbody/images.py", line 25, in calculate
# [ 28] 2025-06-25 12:03:59,797 :     g, s = self._render_gas(particle_data, size), self._render_stars(particle_data, size)
# [ 28] 2025-06-25 12:03:59,797 :                                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [ 28] 2025-06-25 12:03:59,797 :   File "/home/selvani/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/tangos/properties/pynbody/images.py", line 48, in _render_stars
# [ 28] 2025-06-25 12:03:59,797 :     return pynbody.plot.stars.render(f.st[pynbody.filt.HighPass('tform',0) & pynbody.filt.BandPass('z', -size / 2, size / 2)],
# [ 28] 2025-06-25 12:03:59,797 :            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [ 28] 2025-06-25 12:03:59,797 :   File "/home/selvani/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/pynbody/plot/stars.py", line 224, in render
# [ 28] 2025-06-25 12:03:59,797 :     renderer = renderers.make_render_pipeline(sim.s, quantity=r_band + '_lum_den', width=width,
# [ 28] 2025-06-25 12:03:59,797 :                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [ 28] 2025-06-25 12:03:59,797 :   File "/home/selvani/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/pynbody/sph/renderers.py", line 906, in make_render_pipeline
# [ 28] 2025-06-25 12:03:59,797 :     renderer.set_quantity(quantity)
# [ 28] 2025-06-25 12:03:59,797 :   File "/home/selvani/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/pynbody/sph/renderers.py", line 255, in set_quantity
# [ 28] 2025-06-25 12:03:59,797 :     qty = self._snapshot[qty]
# [ 28] 2025-06-25 12:03:59,797 :           ~~~~~~~~~~~~~~^^^^^
# [ 28] 2025-06-25 12:03:59,797 :   File "/home/selvani/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/pynbody/snapshot/simsnap.py", line 252, in __getitem__
# [ 28] 2025-06-25 12:03:59,797 :     return self._get_array_with_lazy_actions(i)
# [ 28] 2025-06-25 12:03:59,797 :            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [ 28] 2025-06-25 12:03:59,797 :   File "/home/selvani/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/pynbody/snapshot/simsnap.py", line 366, in _get_array_with_lazy_actions
# [ 28] 2025-06-25 12:03:59,797 :     self.__derive_if_required(name)
# [ 28] 2025-06-25 12:03:59,797 :   File "/home/selvani/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/pynbody/snapshot/simsnap.py", line 383, in __derive_if_required
# [ 28] 2025-06-25 12:03:59,797 :     self._derive_array(name)
# [ 28] 2025-06-25 12:03:59,797 :   File "/home/selvani/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/pynbody/snapshot/subsnap.py", line 379, in _derive_array
# [ 28] 2025-06-25 12:03:59,797 :     self._subsnap_base._derive_array(array_name, self._unifamily)
# [ 28] 2025-06-25 12:03:59,797 :   File "/home/selvani/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/pynbody/snapshot/subsnap.py", line 114, in _derive_array
# [ 28] 2025-06-25 12:03:59,797 :     self._subsnap_base._derive_array(array_name, fam)
# [ 28] 2025-06-25 12:03:59,797 :   File "/home/selvani/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/pynbody/snapshot/subsnap.py", line 379, in _derive_array
# [ 28] 2025-06-25 12:03:59,797 :     self._subsnap_base._derive_array(array_name, self._unifamily)
# [ 28] 2025-06-25 12:03:59,798 :   File "/home/selvani/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/pynbody/snapshot/simsnap.py", line 1580, in _derive_array
# [ 28] 2025-06-25 12:03:59,798 :     result = fn(self[fam])
# [ 28] 2025-06-25 12:03:59,798 :              ^^^^^^^^^^^^^
# [ 28] 2025-06-25 12:03:59,798 :   File "/home/selvani/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/pynbody/analysis/luminosity.py", line 603, in _lum_den_template
# [ 28] 2025-06-25 12:03:59,798 :     val = (10 ** (-0.4 * s[band + "_mag"])) * s['rho'] / s['mass']
# [ 28] 2025-06-25 12:03:59,798 :                                               ~^^^^^^^
# [ 28] 2025-06-25 12:03:59,798 :   File "/home/selvani/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/pynbody/snapshot/simsnap.py", line 252, in __getitem__
# [ 28] 2025-06-25 12:03:59,798 :     return self._get_array_with_lazy_actions(i)
# [ 28] 2025-06-25 12:03:59,798 :            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [ 28] 2025-06-25 12:03:59,798 :   File "/home/selvani/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/pynbody/snapshot/simsnap.py", line 366, in _get_array_with_lazy_actions
# [ 28] 2025-06-25 12:03:59,798 :     self.__derive_if_required(name)
# [ 28] 2025-06-25 12:03:59,798 :   File "/home/selvani/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/pynbody/snapshot/simsnap.py", line 383, in __derive_if_required
# [ 28] 2025-06-25 12:03:59,798 :     self._derive_array(name)
# [ 28] 2025-06-25 12:03:59,798 :   File "/home/selvani/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/pynbody/snapshot/subsnap.py", line 379, in _derive_array
# [ 28] 2025-06-25 12:03:59,798 :     self._subsnap_base._derive_array(array_name, self._unifamily)
# [ 28] 2025-06-25 12:03:59,798 :   File "/home/selvani/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/pynbody/snapshot/simsnap.py", line 1580, in _derive_array
# [ 28] 2025-06-25 12:03:59,798 :     result = fn(self[fam])
# [ 28] 2025-06-25 12:03:59,798 :              ^^^^^^^^^^^^^
# [ 28] 2025-06-25 12:03:59,798 :   File "/home/selvani/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/pynbody/sph/__init__.py", line 85, in rho
# [ 28] 2025-06-25 12:03:59,798 :     sim.kdtree.set_array_ref('smooth', _get_smooth_array_ensuring_compatibility(sim))
# [ 28] 2025-06-25 12:03:59,798 :                                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [ 28] 2025-06-25 12:03:59,798 :   File "/home/selvani/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/pynbody/sph/__init__.py", line 68, in _get_smooth_array_ensuring_compatibility
# [ 28] 2025-06-25 12:03:59,798 :     sim['smooth'] = smooth_ar = smooth(sim)
# [ 28] 2025-06-25 12:03:59,798 :                                 ^^^^^^^^^^^
# [ 28] 2025-06-25 12:03:59,798 :   File "/home/selvani/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/pynbody/sph/__init__.py", line 52, in smooth
# [ 28] 2025-06-25 12:03:59,798 :     sim.kdtree.populate('hsm', config['sph']['smooth-particles'])
# [ 28] 2025-06-25 12:03:59,798 :   File "/home/selvani/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/pynbody/kdtree/__init__.py", line 352, in populate
# [ 28] 2025-06-25 12:03:59,798 :     smx = kdmain.nn_start(self.kdtree, int(nn), self.boxsize)
# [ 28] 2025-06-25 12:03:59,798 :           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [ 28] 2025-06-25 12:03:59,798 : ValueError: Number of smoothing particles exceeds number of particles in tree
# [ 28] 2025-06-25 12:03:59,798 :
# [ 28] 2025-06-25 12:03:59,798 : If this error arises again, it will be counted but not individually reported.
# [  1] 2025-06-25 12:04:29,845 : Done with <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000384' z=4.57 t=1.31 Gyr>
# [  0] 2025-06-25 12:04:30,003 : Closing snapshot pioneer50h128.1536gst1.bwK1.000384 after processing 876 array fetches
# [  0] 2025-06-25 12:04:30,004 :     Summed process waiting time: 1839.3s
# [  1] 2025-06-25 12:04:30,433 : Processing <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000448' z=4.03 t=1.53 Gyr>
# [  1] 2025-06-25 12:04:30,462 : Missing prerequisites - added class <class 'tangos.properties.pynbody.centring.CentreAndRadius'>
# [  1] 2025-06-25 12:04:30,463 :                         providing properties ('shrink_center', 'max_radius')
# [  1] 2025-06-25 12:04:30,940 : User-specified inclusion criterion excluded 337 of 410 halos
# [  1] 2025-06-25 12:04:43,254 : Successfully gathered existing properties; calculating halo properties now...
# [  1] 2025-06-25 12:04:43,254 :   73 halos to consider; 4 calculation routines for each of them, resulting in 14 properties per halo
# [  1] 2025-06-25 12:04:43,254 :   The property modules are:
# [  1] 2025-06-25 12:04:43,254 :     tangos.properties.pynbody.centring.CentreAndRadius
# [  1] 2025-06-25 12:04:43,254 :     tangos.properties.pynbody.profile.HaloDensityProfile
# [  1] 2025-06-25 12:04:43,254 :     tangos.properties.pynbody.profile.BaryonicHaloDensityProfile
# [  1] 2025-06-25 12:04:43,254 :     tangos.properties.pynbody.images.BaryonicImages
# [  0] 2025-06-25 12:04:43,558 : Pynbody server: loaded 'pioneer50h128.1536gst1.bwK1.000448'
# [  0] 2025-06-25 12:04:43,558 :                 (shared memory mode)
# [  0] 2025-06-25 12:04:43,779 : Generating a shared object catalogue for 'halo's
# [  1] 2025-06-25 12:06:16,343 : Done with <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000448' z=4.03 t=1.53 Gyr>
# [  0] 2025-06-25 12:06:16,508 : Closing snapshot pioneer50h128.1536gst1.bwK1.000448 after processing 879 array fetches
# [  0] 2025-06-25 12:06:16,508 :     Summed process waiting time: 2144.8s
# [  1] 2025-06-25 12:06:16,943 : Processing <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000640' z=2.96 t=2.17 Gyr>
# [  1] 2025-06-25 12:06:16,971 : Missing prerequisites - added class <class 'tangos.properties.pynbody.centring.CentreAndRadius'>
# [  1] 2025-06-25 12:06:16,971 :                         providing properties ('shrink_center', 'max_radius')
# [  1] 2025-06-25 12:06:17,490 : User-specified inclusion criterion excluded 479 of 547 halos
# [  1] 2025-06-25 12:06:29,699 : Successfully gathered existing properties; calculating halo properties now...
# [  1] 2025-06-25 12:06:29,699 :   68 halos to consider; 4 calculation routines for each of them, resulting in 14 properties per halo
# [  1] 2025-06-25 12:06:29,699 :   The property modules are:
# [  1] 2025-06-25 12:06:29,699 :     tangos.properties.pynbody.centring.CentreAndRadius
# [  1] 2025-06-25 12:06:29,700 :     tangos.properties.pynbody.profile.HaloDensityProfile
# [  1] 2025-06-25 12:06:29,700 :     tangos.properties.pynbody.profile.BaryonicHaloDensityProfile
# [  1] 2025-06-25 12:06:29,700 :     tangos.properties.pynbody.images.BaryonicImages
# [  0] 2025-06-25 12:06:30,040 : Pynbody server: loaded 'pioneer50h128.1536gst1.bwK1.000640'
# [  0] 2025-06-25 12:06:30,041 :                 (shared memory mode)
# [  0] 2025-06-25 12:06:30,259 : Generating a shared object catalogue for 'halo's
# [ 28] 2025-06-25 12:08:04,365 : Uncaught exception ValueError('Number of smoothing particles exceeds number of particles in tree') during property calculation <tangos.properties.pynbody.images.BaryonicImages object at 0x7f808464dcd0> applied to <Halo 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000640/halo_82' | NDM=5940 Nstar=7 Ngas=0>
# [ 28] 2025-06-25 12:08:04,368 : Traceback (most recent call last):
# [ 28] 2025-06-25 12:08:04,368 :   File "/home/selvani/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/pynbody/units.py", line 306, in ratio
# [ 28] 2025-06-25 12:08:04,368 :     return (self / other).dimensionless_constant(**substitutions)
# [ 28] 2025-06-25 12:08:04,368 :            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [ 28] 2025-06-25 12:08:04,368 :   File "/home/selvani/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/pynbody/units.py", line 715, in dimensionless_constant
# [ 28] 2025-06-25 12:08:04,369 :     raise UnitsException("Not dimensionless")
# [ 28] 2025-06-25 12:08:04,369 : pynbody.units.UnitsException: Not dimensionless
# [ 28] 2025-06-25 12:08:04,369 :
# [ 28] 2025-06-25 12:08:04,369 : During handling of the above exception, another exception occurred:
# [ 28] 2025-06-25 12:08:04,369 :
# [ 28] 2025-06-25 12:08:04,369 : Traceback (most recent call last):
# [ 28] 2025-06-25 12:08:04,369 :   File "/home/selvani/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/pynbody/sph/renderers.py", line 323, in _units_imply_projection
# [ 28] 2025-06-25 12:08:04,369 :     self._array.units.ratio(units_, **self._snapshot.conversion_context())
# [ 28] 2025-06-25 12:08:04,370 :   File "/home/selvani/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/pynbody/units.py", line 308, in ratio
# [ 28] 2025-06-25 12:08:04,370 :     raise UnitsException("Not convertible")
# [ 28] 2025-06-25 12:08:04,370 : pynbody.units.UnitsException: Not convertible
# [ 28] 2025-06-25 12:08:04,370 :
# [ 28] 2025-06-25 12:08:04,370 : During handling of the above exception, another exception occurred:
# [ 28] 2025-06-25 12:08:04,370 :
# [ 28] 2025-06-25 12:08:04,370 : Traceback (most recent call last):
# [ 28] 2025-06-25 12:08:04,371 :   File "/home/selvani/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/tangos/tools/property_writer.py", line 421, in _get_property_value
# [ 28] 2025-06-25 12:08:04,371 :     result = property_calculator.calculate(snapshot_data, db_data)
# [ 28] 2025-06-25 12:08:04,371 :              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [ 28] 2025-06-25 12:08:04,371 :   File "/home/selvani/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/tangos/properties/pynbody/centring.py", line 97, in new_fn
# [ 28] 2025-06-25 12:08:04,371 :     return fn(self, halo, existing_properties)
# [ 28] 2025-06-25 12:08:04,371 :            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [ 28] 2025-06-25 12:08:04,371 :   File "/home/selvani/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/tangos/properties/pynbody/images.py", line 25, in calculate
# [ 28] 2025-06-25 12:08:04,371 :     g, s = self._render_gas(particle_data, size), self._render_stars(particle_data, size)
# [ 28] 2025-06-25 12:08:04,371 :            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [ 28] 2025-06-25 12:08:04,372 :   File "/home/selvani/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/tangos/properties/pynbody/images.py", line 41, in _render_gas
# [ 28] 2025-06-25 12:08:04,372 :     return self._render_projected(f.gas, size)
# [ 28] 2025-06-25 12:08:04,372 :            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [ 28] 2025-06-25 12:08:04,372 :   File "/home/selvani/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/tangos/properties/pynbody/images.py", line 35, in _render_projected
# [ 28] 2025-06-25 12:08:04,372 :     im = pynbody.plot.sph.image(f, 'rho', size, units="Msol kpc^-2", noplot=True, restrict_depth=True,
# [ 28] 2025-06-25 12:08:04,372 :          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [ 28] 2025-06-25 12:08:04,372 :   File "/home/selvani/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/pynbody/plot/sph.py", line 651, in image
# [ 28] 2025-06-25 12:08:04,372 :     renderer = renderers.make_render_pipeline(sim, quantity=qty, width=width, resolution=resolution,
# [ 28] 2025-06-25 12:08:04,373 :                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [ 28] 2025-06-25 12:08:04,373 :   File "/home/selvani/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/pynbody/sph/renderers.py", line 909, in make_render_pipeline
# [ 28] 2025-06-25 12:08:04,373 :     renderer.set_output_units(out_units)
# [ 28] 2025-06-25 12:08:04,373 :   File "/home/selvani/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/pynbody/sph/renderers.py", line 280, in set_output_units
# [ 28] 2025-06-25 12:08:04,373 :     self._is_projected = self._units_imply_projection(units)
# [ 28] 2025-06-25 12:08:04,373 :                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [ 28] 2025-06-25 12:08:04,373 :   File "/home/selvani/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/pynbody/sph/renderers.py", line 329, in _units_imply_projection
# [ 28] 2025-06-25 12:08:04,373 :     projected_units = self._get_native_units_with_projection()
# [ 28] 2025-06-25 12:08:04,374 :                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [ 28] 2025-06-25 12:08:04,374 :   File "/home/selvani/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/pynbody/sph/renderers.py", line 316, in _get_native_units_with_projection
# [ 28] 2025-06-25 12:08:04,374 :     / self._get_native_area_unit(self._snapshot['smooth'], 2))
# [ 28] 2025-06-25 12:08:04,374 :                                  ~~~~~~~~~~~~~~^^^^^^^^^^
# [ 28] 2025-06-25 12:08:04,374 :   File "/home/selvani/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/pynbody/snapshot/simsnap.py", line 252, in __getitem__
# [ 28] 2025-06-25 12:08:04,374 :     return self._get_array_with_lazy_actions(i)
# [ 28] 2025-06-25 12:08:04,374 :            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [ 28] 2025-06-25 12:08:04,374 :   File "/home/selvani/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/pynbody/snapshot/simsnap.py", line 366, in _get_array_with_lazy_actions
# [ 28] 2025-06-25 12:08:04,374 :     self.__derive_if_required(name)
# [ 28] 2025-06-25 12:08:04,374 :   File "/home/selvani/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/pynbody/snapshot/simsnap.py", line 383, in __derive_if_required
# [ 28] 2025-06-25 12:08:04,375 :     self._derive_array(name)
# [ 28] 2025-06-25 12:08:04,375 :   File "/home/selvani/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/pynbody/snapshot/subsnap.py", line 379, in _derive_array
# [ 28] 2025-06-25 12:08:04,375 :     self._subsnap_base._derive_array(array_name, self._unifamily)
# [ 28] 2025-06-25 12:08:04,375 :   File "/home/selvani/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/pynbody/snapshot/simsnap.py", line 1580, in _derive_array
# [ 28] 2025-06-25 12:08:04,375 :     result = fn(self[fam])
# [ 28] 2025-06-25 12:08:04,375 :              ^^^^^^^^^^^^^
# [ 28] 2025-06-25 12:08:04,375 :   File "/home/selvani/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/pynbody/sph/__init__.py", line 52, in smooth
# [ 28] 2025-06-25 12:08:04,375 :     sim.kdtree.populate('hsm', config['sph']['smooth-particles'])
# [ 28] 2025-06-25 12:08:04,375 :   File "/home/selvani/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/pynbody/kdtree/__init__.py", line 352, in populate
# [ 28] 2025-06-25 12:08:04,376 :     smx = kdmain.nn_start(self.kdtree, int(nn), self.boxsize)
# [ 28] 2025-06-25 12:08:04,376 :           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [ 28] 2025-06-25 12:08:04,376 : ValueError: Number of smoothing particles exceeds number of particles in tree
# [ 28] 2025-06-25 12:08:04,376 :
# [ 28] 2025-06-25 12:08:04,376 : If this error arises again, it will be counted but not individually reported.
# [  1] 2025-06-25 12:08:13,222 : Done with <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000640' z=2.96 t=2.17 Gyr>
# [  0] 2025-06-25 12:08:13,385 : Closing snapshot pioneer50h128.1536gst1.bwK1.000640 after processing 882 array fetches
# [  0] 2025-06-25 12:08:13,385 :     Summed process waiting time: 2273.8s
# [  1] 2025-06-25 12:09:50,227 : Processing <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000832' z=2.32 t=2.82 Gyr>
# [  1] 2025-06-25 12:09:50,291 : Missing prerequisites - added class <class 'tangos.properties.pynbody.centring.CentreAndRadius'>
# [  1] 2025-06-25 12:09:50,291 :                         providing properties ('shrink_center', 'max_radius')
# [  1] 2025-06-25 12:09:50,517 : User-specified inclusion criterion excluded 604 of 666 halos
# [  1] 2025-06-25 12:09:50,685 : Successfully gathered existing properties; calculating halo properties now...
# [  1] 2025-06-25 12:09:50,685 :   62 halos to consider; 4 calculation routines for each of them, resulting in 14 properties per halo
# [  1] 2025-06-25 12:09:50,686 :   The property modules are:
# [  1] 2025-06-25 12:09:50,686 :     tangos.properties.pynbody.centring.CentreAndRadius
# [  1] 2025-06-25 12:09:50,686 :     tangos.properties.pynbody.profile.HaloDensityProfile
# [  1] 2025-06-25 12:09:50,686 :     tangos.properties.pynbody.profile.BaryonicHaloDensityProfile
# [  1] 2025-06-25 12:09:50,686 :     tangos.properties.pynbody.images.BaryonicImages
# [  0] 2025-06-25 12:09:51,044 : Pynbody server: loaded 'pioneer50h128.1536gst1.bwK1.000832'
# [  0] 2025-06-25 12:09:51,044 :                 (shared memory mode)
# [  0] 2025-06-25 12:09:51,276 : Generating a shared object catalogue for 'halo's
# [  1] 2025-06-25 12:11:41,898 : Done with <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000832' z=2.32 t=2.82 Gyr>
# [  0] 2025-06-25 12:11:42,059 : Closing snapshot pioneer50h128.1536gst1.bwK1.000832 after processing 867 array fetches
# [  0] 2025-06-25 12:11:42,060 :     Summed process waiting time: 2364.4s
# [  1] 2025-06-25 12:11:42,517 : Processing <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000960' z=2.02 t=3.25 Gyr>
# [  1] 2025-06-25 12:11:42,554 : Missing prerequisites - added class <class 'tangos.properties.pynbody.centring.CentreAndRadius'>
# [  1] 2025-06-25 12:11:42,554 :                         providing properties ('shrink_center', 'max_radius')
# [  1] 2025-06-25 12:11:42,765 : User-specified inclusion criterion excluded 666 of 719 halos
# [  1] 2025-06-25 12:11:42,782 : Successfully gathered existing properties; calculating halo properties now...
# [  1] 2025-06-25 12:11:42,783 :   53 halos to consider; 4 calculation routines for each of them, resulting in 14 properties per halo
# [  1] 2025-06-25 12:11:42,783 :   The property modules are:
# [  1] 2025-06-25 12:11:42,783 :     tangos.properties.pynbody.centring.CentreAndRadius
# [  1] 2025-06-25 12:11:42,783 :     tangos.properties.pynbody.profile.HaloDensityProfile
# [  1] 2025-06-25 12:11:42,783 :     tangos.properties.pynbody.profile.BaryonicHaloDensityProfile
# [  1] 2025-06-25 12:11:42,783 :     tangos.properties.pynbody.images.BaryonicImages
# [  0] 2025-06-25 12:11:43,070 : Pynbody server: loaded 'pioneer50h128.1536gst1.bwK1.000960'
# [  0] 2025-06-25 12:11:43,070 :                 (shared memory mode)
# [  0] 2025-06-25 12:11:43,291 : Generating a shared object catalogue for 'halo's
# [  0] 2025-06-25 12:12:56,387 :
# [  0] 2025-06-25 12:12:56,388 : CUMULATIVE RESPONSE WAIT, summed over all processes, if applicable
# [  0] 2025-06-25 12:12:56,388 :       CreateNewAccumulatorMessageResponse        0.26s
# [  0] 2025-06-25 12:12:56,389 :              SimpleBarrierMessageResponse       9m 38s
# [  0] 2025-06-25 12:12:56,394 :           MessageRequestCreatorIdResponse         3.4s
# [  0] 2025-06-25 12:12:56,394 :             MessageStartIterationResponse        0.35s
# [  0] 2025-06-25 12:12:56,395 :                 MessageRequestJobResponse       1m 34s
# [  0] 2025-06-25 12:12:56,395 :                          MessageGrantLock      27m 30s
# [  0] 2025-06-25 12:12:56,395 :                ConfirmLoadPynbodySnapshot        15.0s
# [  0] 2025-06-25 12:12:56,395 :                  ReturnPynbodySubsnapInfo        21.3s
# [  0] 2025-06-25 12:12:56,395 :                 ReturnSharedObjectCatalog      19m 12s
# [  0] 2025-06-25 12:12:56,395 :                     SharedMemoryArrayInfo        0.09s
# [  0] 2025-06-25 12:12:56,395 :                        ReturnPynbodyArray    1h 45m 8s
# [  0] 2025-06-25 12:12:56,395 :                RemoteSetOperationResponse        10.1s
# [  0] 2025-06-25 12:12:56,395 :
# [  0] 2025-06-25 12:12:56,395 :
# [  0] 2025-06-25 12:12:56,395 : CUMULATIVE RUNNING TIMES, summed over all processes, if applicable
# [  0] 2025-06-25 12:12:56,395 :       CentreAndRadius      31m 35s | 26.6%
# [  0] 2025-06-25 12:12:56,395 :   ------------ INTERNAL BREAKDOWN ------------
# [  0] 2025-06-25 12:12:56,395 :        start cen           31m 26s | 99.5% | 26.5%
# [  0] 2025-06-25 12:12:56,395 :          cen end              9.1s |  0.5% |  0.1%
# [  0] 2025-06-25 12:12:56,395 :   --------------------------------------------
# [  0] 2025-06-25 12:12:56,395 :    HaloDensityProfile        10.7s |  0.2%
# [  0] 2025-06-25 12:12:56,395 :  icHaloDensityProfile      10m 58s |  9.2%
# [  0] 2025-06-25 12:12:56,396 :        BaryonicImages   1h 15m 54s | 64.0%
# [  0] 2025-06-25 12:12:56,396 :
# [  0] 2025-06-25 12:12:56,396 : PROPERTY CALCULATION SUMMARY
# [  0] 2025-06-25 12:12:56,396 :             Succeeded: 770 property calculations
# [  0] 2025-06-25 12:12:56,396 :               Errored: 54 property calculations
# [  0] 2025-06-25 12:12:56,396 :   Errored during load: 0 property calculations
# [  0] 2025-06-25 12:12:56,396 :        Already exists: 0 property calculations
# [  0] 2025-06-25 12:12:56,396 : Missing pre-requisite: 0 property calculations
# [  1] 2025-06-25 12:13:47,127 : Done with <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000960' z=2.02 t=3.25 Gyr>
# [  0] 2025-06-25 12:13:47,288 : Closing snapshot pioneer50h128.1536gst1.bwK1.000960 after processing 845 array fetches
# [  0] 2025-06-25 12:13:47,289 :     Summed process waiting time: 2396.1s
# [  0] 2025-06-25 12:14:58,489 :
# [  0] 2025-06-25 12:14:58,489 : CUMULATIVE RESPONSE WAIT, summed over all processes, if applicable
# [  0] 2025-06-25 12:14:58,489 :       CreateNewAccumulatorMessageResponse        0.26s
# [  0] 2025-06-25 12:14:58,489 :              SimpleBarrierMessageResponse    1h 8m 33s
# [  0] 2025-06-25 12:14:58,489 :           MessageRequestCreatorIdResponse         3.4s
# [  0] 2025-06-25 12:14:58,489 :             MessageStartIterationResponse         1.2s
# [  0] 2025-06-25 12:14:58,489 :                 MessageRequestJobResponse       3m 54s
# [  0] 2025-06-25 12:14:58,489 :                          MessageGrantLock       38m 5s
# [  0] 2025-06-25 12:14:58,489 :                ConfirmLoadPynbodySnapshot        21.7s
# [  0] 2025-06-25 12:14:58,489 :                  ReturnPynbodySubsnapInfo        36.1s
# [  0] 2025-06-25 12:14:58,490 :                 ReturnSharedObjectCatalog      41m 33s
# [  0] 2025-06-25 12:14:58,490 :                     SharedMemoryArrayInfo        0.15s
# [  0] 2025-06-25 12:14:58,490 :                        ReturnPynbodyArray     3h 5m 4s
# [  0] 2025-06-25 12:14:58,490 :                RemoteSetOperationResponse       1m 22s
# [  0] 2025-06-25 12:14:58,490 :
# [  0] 2025-06-25 12:14:58,490 :
# [  0] 2025-06-25 12:14:58,490 : CUMULATIVE RUNNING TIMES, summed over all processes, if applicable
# [  0] 2025-06-25 12:14:58,490 :       CentreAndRadius      55m 28s | 27.6%
# [  0] 2025-06-25 12:14:58,490 :   ------------ INTERNAL BREAKDOWN ------------
# [  0] 2025-06-25 12:14:58,490 :        start cen           55m 14s | 99.6% | 27.4%
# [  0] 2025-06-25 12:14:58,490 :          cen end             14.1s |  0.4% |  0.1%
# [  0] 2025-06-25 12:14:58,491 :   --------------------------------------------
# [  0] 2025-06-25 12:14:58,491 :    HaloDensityProfile        20.1s |  0.2%
# [  0] 2025-06-25 12:14:58,491 :  icHaloDensityProfile      18m 43s |  9.3%
# [  0] 2025-06-25 12:14:58,491 :        BaryonicImages    2h 6m 45s | 63.0%
# [  0] 2025-06-25 12:14:58,491 :
# [  0] 2025-06-25 12:14:58,491 : PROPERTY CALCULATION SUMMARY
# [  0] 2025-06-25 12:14:58,491 :             Succeeded: 1195 property calculations
# [  0] 2025-06-25 12:14:58,491 :               Errored: 89 property calculations
# [  0] 2025-06-25 12:14:58,491 :   Errored during load: 0 property calculations
# [  0] 2025-06-25 12:14:58,491 :        Already exists: 0 property calculations
# [  0] 2025-06-25 12:14:58,491 : Missing pre-requisite: 0 property calculations

# %%
# %matplotlib inline
import pylab as p

# !tangos import-properties uvi_image --for tutorial_changa

halo = tangos.get_halo("tutorial_changa/%960/halo_1")
halo.keys()

p.imshow(halo['uvi_image'])
p.show()

# %% [markdown]
# ## Actual Tutorial

# %%
import os
os.environ['TANGOS_SIMULATION_FOLDER'] = '/home/selvani/MAP/Tangos/testdata'
os.environ['TANGOS_DB_CONNECTION'] = '/home/selvani/MAP/tangos_data.db'

# %%
# %matplotlib inline
import pylab as p

import tangos

# %% [markdown]
# First let's inspect what simulations are available in our database:

# %%
tangos.all_simulations()
# Out:
# 2025-06-25 10:52:42,628 : The database uses an old schema, missing the finder_offset column from halos. Attempting to update.
# 2025-06-25 10:52:42,908 : The database update appeared to complete without any problems.
# [<Simulation("tutorial_ramses")>,
#  <Simulation("tutorial_gadget")>,
#  <Simulation("tutorial_changa")>,
#  <Simulation("tutorial_changa_blackholes")>]

# %% [markdown]
# For any of these simulations, we can generate a list of available timesteps as follows:

# %%
tangos.get_simulation("tutorial_changa").timesteps
# Out:
# [<TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000384' z=4.57 t=1.31 Gyr>,
#  <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000448' z=4.03 t=1.53 Gyr>,
#  <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000640' z=2.96 t=2.17 Gyr>,
#  <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000832' z=2.32 t=2.82 Gyr>,
#  <TimeStep 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000960' z=2.02 t=3.25 Gyr>]

# %% [markdown]
# For any timestep, we can access the halos using `.halos` and a specific halo using standard python 0-based indexing:

# %%
tangos.get_simulation("tutorial_changa").timesteps[3].halos[3]
# Out:
# <Halo 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000832/halo_4' | NDM=199525 Nstar=7531 Ngas=19920>

# %% [markdown]
# One can skip straight to getting a specific halo as follows:

# %%
tangos.get_halo("tutorial_changa/%384/halo_4")
# Out:
# <Halo 'tutorial_changa/pioneer50h128.1536gst1.bwK1.000384/halo_4' | NDM=87599 Nstar=1900 Ngas=9220>

# %% [markdown]
# Note the use of the SQL wildcard % character which avoids us having to type out the entire path. Whatever way you access it, the resulting object allows you to query what properties have been calculated for that specific halo. We can then access those properties using the normal python square-bracket dictionary syntax.

# %%
halo = tangos.get_halo("tutorial_changa/%960/halo_1")
halo.keys()
# Out:
# ['contamination_fraction',
#  'shrink_center',
#  'max_radius',
#  'dm_density_profile',
#  'dm_mass_profile',
#  'gas_density_profile',
#  'gas_mass_profile',
#  'star_density_profile',
#  'star_mass_profile',
#  'gas_map_sideon',
#  'uvi_image_sideon',
#  'gas_map_faceon',
#  'uvi_image_faceon',
#  'gas_map',
#  'uvi_image',
#  'SFR_histogram',
#  'Mvir',
#  'Rvir',
#  'ptcls_in_common',
#  'ptcls_in_common',
#  'ptcls_in_common',
#  'ptcls_in_common',
#  'ptcls_in_common',
#  'ptcls_in_common',
#  'ptcls_in_common']

# %%
halo['Mvir']
# Out:
# 637727000000.0

# %%
p.imshow(halo['uvi_image'])
p.show()

# %% [markdown]
# One can also get meta-information about the computed property. It would be nice to know
# the physical size of the image we just plotted. We retrieve the underlying property object
# and ask it:

# %%
halo.get_description("uvi_image").plot_extent()
# Out:
# 15.0

# %% [markdown]
# This tells us that the image is 15 kpc across. The example properties that come with _tangos_
# use _pynbody_'s units system to convert everything to physical kpc, solar masses and km/s. When
# you implement your own properties, you can of course store them in whichever units you like.

# %% [markdown]
# Getting a time sequence of properties
# -------------------------------------
#
# Often we would like to see how a property varies over time. _Tangos_ provides convenient ways to extract this information, automatically finding
# major progenitors or descendants for a halo. Let's see this illustrated on the SubFind _mass_ property:

# %%
halo = tangos.get_halo("tutorial_gadget/snapshot_020/halo_10")

# Calculate on major progenitor branch:
Mvir, t = halo.calculate_for_progenitors("mass","t()")

# Now perform plotting:
p.plot(t,1e10*Mvir)
p.xlabel("t/Gyr")
p.ylabel(r"$M/h^{-1} M_{\odot}$")
p.semilogy()
p.show()

# %% [markdown]
# In the example above, `calculate_for_progenitors` retrieves properties on the major progenitor branch of the chosen halo. One can ask for as many properties as you like, each one being returned as a numpy array in order. In this particular example the first property is the mass (as reported by subfind) and the second is the time. In fact the second property isn't really stored - if you check `halo.keys()` you won't find `t` in there. It's a simple example of a _live property_ which means it's calculated on-the-fly from other data. The time is actually stored in the TimeStep rather than the Halo database entry, so the `t()` live property simply retrieves it from the appropriate location.
#
# Live properties are a powerful aspect of _tangos_. We'll see more of them momentarily.

# %% [markdown]
# Histogram properties
# --------------------
#
# While the approach above is the main way to get time series of data with _tangos_, sometimes one
# wants to be able to use finer time bins than the number of outputs available. For example, star
# formation rates or black hole accretion rates often vary on short timescales and the output files
# from simulations are sufficient to reconstruct these variations in between snapshots.
#
# _Tangos_ implements `TimeChunkedHistogram` for this purpose. As the name suggests, a _chunk_ of
# historical data is stored with each timestep. The full history is then reconstructed by combining
# the chunks through the merger tree; this process is customizable. Let's start with the simplest
# possible request:

# %%
halo = tangos.get_halo("tutorial_changa_blackholes/%960/halo_1")
SFR = halo["SFR_histogram"]

# The above is sufficient to retrieve the histogram; however you probably also want to check
# the size of the time bins. The easiest approach is to request a suitable time array to go with
# the SF history:
SFR_property_object = halo.get_objects("SFR_histogram")[0]
SFR_time_bins = SFR_property_object.x_values()

p.plot(SFR_time_bins, SFR)
p.xlabel("Time/Gyr")
p.ylabel(r"SFR/$M_{\odot}\,yr^{-1}$")
p.show()

# %% [markdown]
# The advantage of storing the histogram in chunks is that one can reconstruct it
# in different ways. The default is to go along the major progenitor branch, but
# one can also sum over all progenitors. The following code shows the fraction of
# star formation in the major progenitor:

# %%
SFR_all = halo.calculate('reassemble(SFR_histogram, "sum")')
p.plot(SFR_time_bins, SFR/SFR_all)
p.xlabel("Time/Gyr")
p.ylabel("Frac. SFR in major progenitor")
p.show()
# Out:
# /tmp/ipykernel_24109/242916581.py:2: RuntimeWarning: invalid value encountered in divide
#   p.plot(SFR_time_bins, SFR/SFR_all)

# %% [markdown]
# _Technical note_: It's worth being aware that the merger information is, of course, quantized to the
# output timesteps even though the SFR information is stored in small chunks. This is rarely an issue
# but with coarse timesteps (such as those in the tutorial simulations), the quantization can cause
# noticable artefacts – here, the jump to 100% in the major progenitor shortly before _t_ = 3 Gyr
# corresponds to the time of the penultimate stored step, after which no mergers are recorded.
#
# For more information, see the [time-histogram properties](https://pynbody.github.io/tangos/histogram_properties.html) page.

# %% [markdown]
# Let's see another example of a histogram property: the black hole accretion rate

# %%
BH_accrate = halo.calculate('BH.BH_mdot_histogram')
p.plot(SFR_time_bins, BH_accrate)
p.xlabel("Time/Gyr")
p.ylabel(r"BH accretion rate/$M_{\odot}\,yr^{-1}$")
p.show()
# Out:
# /home/selvani/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/tangos/live_calculation/__init__.py:637: RuntimeWarning: More than one relation for target 'BH' has been found. Picking the first.
#   warnings.warn("More than one relation for target %r has been found. Picking the first."%str(self.locator), RuntimeWarning)

# %% [markdown]
# This works fine, but you may have noticed the warning that more than one black hole
# is in the halo of interest. There is more information about the way that links between
# objects work in _tangos_, and disambiguating between them, in the "using links" section
# below.

# %% [markdown]
# Getting properties for multiple halos
# -------------------------------------
#
# Quite often one wants to collect properties from multiple halos simultaneously. Suppose we want to plot the mass against the vmax for all halos at
# a specific snapshot:

# %%
timestep = tangos.get_timestep("tutorial_gadget/snapshot_019")
mass, vmax = timestep.calculate_all("mass","VMax")

p.plot(mass*1e10,vmax,'k.')
p.loglog()
p.xlabel(r"$M/h^{-1} M_{\odot}$")
p.ylabel(r"$v_{max}/{\rm km s^{-1}}$")
p.show()

# %% [markdown]
# Often when querying multiple halos we still want to know something about their history, and live calculations enable that. Suppose we want to know how much the mass has grown since the previous snapshot:

# %%
mass, fractional_delta_2 = timestep.calculate_all("mass",  "(mass-earlier(2).mass)/mass")

p.hlines(0.0,1e10,1e15, colors="gray")
p.plot(mass*1e10, fractional_delta_2,"r.", alpha=0.2)
p.semilogx()
p.ylim(-0.1,0.9)
p.xlim(1e12,1e15)
p.xlabel(r"$M/h^{-1} M_{\odot}$")
p.ylabel("Fractional growth in mass")
p.show()

# %% [markdown]
# This is a much more ambitious use of the live calculation system. Consider the last property retrieved, which is `(mass-earlier(2).mass)/mass`. This combines algebraic operations with _redirection_: `earlier(2)` finds the major progenitor two steps prior to this one, after which `.mass` retrieves the mass at that earlier timestep. This is another example of a "link", as previously used to retrieve
# black hole information above.

# %% [markdown]
# Using Links
# -----------
#
# _Tangos_ has a concept of "links" between objects including halos and black holes. For example,
# the merger tree information that you have already used indirectly is stored as links.
#
# Returning to our example of black holes above, we used a link named `BH`; however this issued a
# warning that the result was technically ambiguous. Let's see that warning again. For clarity,
# we will use the link named `BH_central` this time around -- it's an alternative set of links
# which only includes black holes associated with the central galaxy (rather than any satellites).

# %%
halo = tangos.get_halo("tutorial_changa_blackholes/%960/halo_1")
BH_mass = halo.calculate('BH_central.BH_mass')
# Out:
# /home/selvani/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/tangos/live_calculation/__init__.py:637: RuntimeWarning: More than one relation for target 'BH_central' has been found. Picking the first.
#   warnings.warn("More than one relation for target %r has been found. Picking the first."%str(self.locator), RuntimeWarning)

# %% [markdown]
# We still get the warning, so there's more than one black hole in the central galaxy.
#
# To avoid such warnings, you can specify more about which link you are referring to. For example,
# we can specifically ask for the black hole with the _largest mass_ and _smallest impact parameters_
# using the following two queries:

# %%
BH_max_mass = halo.calculate('link(BH_central, BH_mass, "max")')
BH_closest = halo.calculate('link(BH_central, BH_central_distance, "min")')

# %% [markdown]
# The `link` live-calculation function returns the halo with either the maximum or minimum value of an
# associated property, here the `BH_mass` and `BH_central_distance` properties respectively.
# Either approach disambiguates the black holes we mean (in fact, they unsurprisingly lead to
# the same disambiguation):

# %%
BH_max_mass == BH_closest
# Out:
# True

# %% [markdown]
# However one doesn't always have to name a link to make use of it. The mere existence of a link
# is sometimes enough. An example is the merger tree information already used. Another useful
# example is when two simulations have the same initial conditions, as in the `tutorial_changa`
# and `tutorial_changa_blackholes` examples; these two simulations differ only in that the latter
# has AGN feedback. We can identify halos between simulations using the following syntax:

# %%
SFR_in_other_sim = halo.calculate("match('tutorial_changa').SFR_histogram")
p.plot(SFR_time_bins, halo['SFR_histogram'],color='r', label="With AGN feedback")
p.plot(SFR_time_bins, SFR_in_other_sim, color='b',label="No AGN feedback")
p.legend(loc="lower right")
p.semilogy()
p.xlabel("t/Gyr")
p.ylabel(r"SFR/$M_{\odot}\,yr^{-1}$")
p.show()

# %% [markdown]
# The `match` syntax simply tries to follow links until it finds a halo in the named
# _tangos_ context. One can use it to match halos across entire timesteps too; let's
# compare the stellar masses of our objects:

# %%
timestep = tangos.get_timestep("tutorial_changa/%960")
Mstar_no_AGN, Mstar_AGN = timestep.calculate_all("star_mass_profile[-1]", 
                                                 "match('tutorial_changa_blackholes').star_mass_profile[-1]")
# note that we use star_mass_profile[-1] to get the last entry of the star_mass_profile array,
# as a means to get the total stellar mass from a profile
p.plot(Mstar_no_AGN, Mstar_AGN, 'k.')
p.plot([1e6,1e11],[1e6,1e11],'k-',alpha=0.3)
p.loglog()
p.xlabel(r"$M_{\star}/M_{\odot}$ without AGN")
p.ylabel(r"$M_{\star}/M_{\odot}$ with AGN")
p.show()
