# %% [markdown]
# ## Tangos

# %%
import os
os.environ['TANGOS_SIMULATION_FOLDER'] = '/home/selvani/MAP/Sims/cptmarvel.cosmo25cmb/cptmarvel.cosmo25cmb.4096g5HbwK1BH/'
os.environ['TANGOS_DB_CONNECTION'] = '/home/selvani/MAP/Data/Marvel_BN_N10.db'

# %%
import tangos
tangos.all_simulations()
# Out:
# [<Simulation("cptmarvel.4096g5HbwK1BH_bn")>]

# %%
tangos.get_simulation("cptmarvel.4096g5HbwK1BH_bn").timesteps
# Out:
# [<TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000291' z=5.99 t=0.99 Gyr>,
#  <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000384' z=4.81 t=1.30 Gyr>,
#  <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000482' z=4.00 t=1.63 Gyr>,
#  <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000512' z=3.80 t=1.73 Gyr>,
#  <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000640' z=3.13 t=2.15 Gyr>,
#  <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000672' z=3.00 t=2.26 Gyr>,
#  <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000768' z=2.65 t=2.58 Gyr>,
#  <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000818' z=2.50 t=2.75 Gyr>,
#  <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000896' z=2.29 t=3.01 Gyr>,
#  <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.001025' z=2.00 t=3.44 Gyr>,
#  <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.001152' z=1.77 t=3.87 Gyr>,
#  <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.001162' z=1.75 t=3.90 Gyr>,
#  <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.001280' z=1.57 t=4.30 Gyr>,
#  <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.001331' z=1.50 t=4.47 Gyr>,
#  <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.001408' z=1.40 t=4.73 Gyr>,
#  <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.001536' z=1.26 t=5.16 Gyr>,
#  <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.001543' z=1.25 t=5.18 Gyr>,
#  <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.001664' z=1.13 t=5.58 Gyr>,
#  <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.001792' z=1.02 t=6.01 Gyr>,
#  <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.001813' z=1.00 t=6.08 Gyr>,
#  <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.001920' z=0.92 t=6.44 Gyr>,
#  <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.002048' z=0.82 t=6.87 Gyr>,
#  <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.002162' z=0.75 t=7.25 Gyr>,
#  <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.002176' z=0.74 t=7.30 Gyr>,
#  <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.002304' z=0.67 t=7.73 Gyr>,
#  <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.002432' z=0.60 t=8.16 Gyr>,
#  <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.002560' z=0.53 t=8.59 Gyr>,
#  <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.002624' z=0.50 t=8.80 Gyr>,
#  <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.002688' z=0.47 t=9.02 Gyr>,
#  <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.002816' z=0.41 t=9.44 Gyr>,
#  <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.002944' z=0.36 t=9.87 Gyr>,
#  <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.003072' z=0.31 t=10.30 Gyr>,
#  <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.003200' z=0.27 t=10.73 Gyr>,
#  <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.003245' z=0.25 t=10.88 Gyr>,
#  <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.003328' z=0.22 t=11.16 Gyr>,
#  <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.003456' z=0.18 t=11.59 Gyr>,
#  <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.003584' z=0.14 t=12.02 Gyr>,
#  <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.003636' z=0.12 t=12.19 Gyr>,
#  <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.003712' z=0.10 t=12.45 Gyr>,
#  <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.003840' z=0.07 t=12.87 Gyr>,
#  <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.003968' z=0.03 t=13.30 Gyr>,
#  <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.004096' z=-0.00 t=13.73 Gyr>]

# %%
halo = tangos.get_halo("cptmarvel.4096g5HbwK1BH_bn/%4096/halo_1")
halo.keys()
# Out:
# ['Mvir',
#  'Rvir',
#  'Xc',
#  'Yc',
#  'Zc',
#  'VXc',
#  'VYc',
#  'VZc',
#  'Vmax',
#  'fMhires',
#  'M_gas',
#  'M_star',
#  'n_gas',
#  'n_star',
#  'n_dm',
#  'npart',
#  'shrink_center',
#  'max_radius',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'childHalo',
#  'ptcls_in_common']

# %%
# !tangos link
# Out:
# 2025-06-25 13:56:29,291 : generating pairs of timesteps
# 2025-06-25 13:56:29,309 : Linking <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000291' z=5.99 t=0.99 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000384' z=4.81 t=1.30 Gyr>
# 2025-06-25 13:56:33,212 : Will not link: links already exist between <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000291' z=5.99 t=0.99 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000384' z=4.81 t=1.30 Gyr>
# 2025-06-25 13:56:33,235 : Linking <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000384' z=4.81 t=1.30 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000482' z=4.00 t=1.63 Gyr>
# 2025-06-25 13:56:35,153 : Will not link: links already exist between <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000384' z=4.81 t=1.30 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000482' z=4.00 t=1.63 Gyr>
# 2025-06-25 13:56:35,178 : Linking <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000482' z=4.00 t=1.63 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000512' z=3.80 t=1.73 Gyr>
# 2025-06-25 13:56:37,405 : Will not link: links already exist between <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000482' z=4.00 t=1.63 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000512' z=3.80 t=1.73 Gyr>
# 2025-06-25 13:56:37,424 : Linking <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000512' z=3.80 t=1.73 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000640' z=3.13 t=2.15 Gyr>
# 2025-06-25 13:56:39,686 : Will not link: links already exist between <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000512' z=3.80 t=1.73 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000640' z=3.13 t=2.15 Gyr>
# 2025-06-25 13:56:39,707 : Linking <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000640' z=3.13 t=2.15 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000672' z=3.00 t=2.26 Gyr>
# 2025-06-25 13:56:42,099 : Will not link: links already exist between <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000640' z=3.13 t=2.15 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000672' z=3.00 t=2.26 Gyr>
# 2025-06-25 13:56:42,124 : Linking <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000672' z=3.00 t=2.26 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000768' z=2.65 t=2.58 Gyr>
# 2025-06-25 13:56:44,373 : Will not link: links already exist between <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000672' z=3.00 t=2.26 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000768' z=2.65 t=2.58 Gyr>
# 2025-06-25 13:56:44,393 : Linking <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000768' z=2.65 t=2.58 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000818' z=2.50 t=2.75 Gyr>
# 2025-06-25 13:56:46,743 : Will not link: links already exist between <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000768' z=2.65 t=2.58 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000818' z=2.50 t=2.75 Gyr>
# 2025-06-25 13:56:46,769 : Linking <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000818' z=2.50 t=2.75 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000896' z=2.29 t=3.01 Gyr>
# 2025-06-25 13:56:48,993 : Will not link: links already exist between <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000818' z=2.50 t=2.75 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000896' z=2.29 t=3.01 Gyr>
# 2025-06-25 13:56:49,014 : Linking <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000896' z=2.29 t=3.01 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.001025' z=2.00 t=3.44 Gyr>
# 2025-06-25 13:56:51,230 : Will not link: links already exist between <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000896' z=2.29 t=3.01 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.001025' z=2.00 t=3.44 Gyr>
# 2025-06-25 13:56:51,250 : Linking <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.001025' z=2.00 t=3.44 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.001152' z=1.77 t=3.87 Gyr>
# 2025-06-25 13:56:53,431 : Will not link: links already exist between <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.001025' z=2.00 t=3.44 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.001152' z=1.77 t=3.87 Gyr>
# 2025-06-25 13:56:53,457 : Linking <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.001152' z=1.77 t=3.87 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.001162' z=1.75 t=3.90 Gyr>
# 2025-06-25 13:56:55,724 : Will not link: links already exist between <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.001152' z=1.77 t=3.87 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.001162' z=1.75 t=3.90 Gyr>
# 2025-06-25 13:56:55,746 : Linking <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.001162' z=1.75 t=3.90 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.001280' z=1.57 t=4.30 Gyr>
# 2025-06-25 13:56:58,379 : Will not link: links already exist between <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.001162' z=1.75 t=3.90 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.001280' z=1.57 t=4.30 Gyr>
# 2025-06-25 13:56:58,398 : Linking <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.001280' z=1.57 t=4.30 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.001331' z=1.50 t=4.47 Gyr>
# 2025-06-25 13:57:00,678 : Will not link: links already exist between <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.001280' z=1.57 t=4.30 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.001331' z=1.50 t=4.47 Gyr>
# 2025-06-25 13:57:00,699 : Linking <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.001331' z=1.50 t=4.47 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.001408' z=1.40 t=4.73 Gyr>
# 2025-06-25 13:57:02,866 : Will not link: links already exist between <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.001331' z=1.50 t=4.47 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.001408' z=1.40 t=4.73 Gyr>
# 2025-06-25 13:57:02,888 : Linking <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.001408' z=1.40 t=4.73 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.001536' z=1.26 t=5.16 Gyr>
# 2025-06-25 13:57:05,205 : Will not link: links already exist between <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.001408' z=1.40 t=4.73 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.001536' z=1.26 t=5.16 Gyr>
# 2025-06-25 13:57:05,229 : Linking <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.001536' z=1.26 t=5.16 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.001543' z=1.25 t=5.18 Gyr>
# 2025-06-25 13:57:07,610 : Will not link: links already exist between <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.001536' z=1.26 t=5.16 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.001543' z=1.25 t=5.18 Gyr>
# 2025-06-25 13:57:07,631 : Linking <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.001543' z=1.25 t=5.18 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.001664' z=1.13 t=5.58 Gyr>
# 2025-06-25 13:57:09,970 : Will not link: links already exist between <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.001543' z=1.25 t=5.18 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.001664' z=1.13 t=5.58 Gyr>
# 2025-06-25 13:57:09,991 : Linking <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.001664' z=1.13 t=5.58 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.001792' z=1.02 t=6.01 Gyr>
# 2025-06-25 13:57:12,202 : Will not link: links already exist between <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.
: Linking <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.003200' z=0.27 t=10.73 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.003245' z=0.25 t=10.88 Gyr>
# 2025-06-25 13:57:47,399 : Will not link: links already exist between <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.003200' z=0.27 t=10.73 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.003245' z=0.25 t=10.88 Gyr>
# 2025-06-25 13:57:47,421 : Linking <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.003245' z=0.25 t=10.88 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.003328' z=0.22 t=11.16 Gyr>
# 2025-06-25 13:57:49,623 : Will not link: links already exist between <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.003245' z=0.25 t=10.88 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.003328' z=0.22 t=11.16 Gyr>
# 2025-06-25 13:57:49,644 : Linking <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.003328' z=0.22 t=11.16 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.003456' z=0.18 t=11.59 Gyr>
# 2025-06-25 13:57:51,978 : Will not link: links already exist between <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.003328' z=0.22 t=11.16 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.003456' z=0.18 t=11.59 Gyr>
# 2025-06-25 13:57:52,001 : Linking <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.003456' z=0.18 t=11.59 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.003584' z=0.14 t=12.02 Gyr>
# 2025-06-25 13:57:54,274 : Will not link: links already exist between <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.003456' z=0.18 t=11.59 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.003584' z=0.14 t=12.02 Gyr>
# 2025-06-25 13:57:54,297 : Linking <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.003584' z=0.14 t=12.02 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.003636' z=0.12 t=12.19 Gyr>
# 2025-06-25 13:57:56,609 : Will not link: links already exist between <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.003584' z=0.14 t=12.02 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.003636' z=0.12 t=12.19 Gyr>
# 2025-06-25 13:57:56,631 : Linking <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.003636' z=0.12 t=12.19 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.003712' z=0.10 t=12.45 Gyr>
# 2025-06-25 13:57:58,841 : Will not link: links already exist between <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.003636' z=0.12 t=12.19 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.003712' z=0.10 t=12.45 Gyr>
# 2025-06-25 13:57:58,863 : Linking <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.003712' z=0.10 t=12.45 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.003840' z=0.07 t=12.87 Gyr>
# 2025-06-25 13:58:01,089 : Will not link: links already exist between <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.003712' z=0.10 t=12.45 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.003840' z=0.07 t=12.87 Gyr>
# 2025-06-25 13:58:01,110 : Linking <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.003840' z=0.07 t=12.87 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.003968' z=0.03 t=13.30 Gyr>
# 2025-06-25 13:58:03,324 : Will not link: links already exist between <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.003840' z=0.07 t=12.87 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.003968' z=0.03 t=13.30 Gyr>
# 2025-06-25 13:58:03,345 : Linking <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.003968' z=0.03 t=13.30 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.004096' z=-0.00 t=13.73 Gyr>
# 2025-06-25 13:58:05,587 : Will not link: links already exist between <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.003968' z=0.03 t=13.30 Gyr> and <TimeStep 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.004096' z=-0.00 t=13.73 Gyr>

# %%
# first, find all the things that merge into the major progenitor branch
import tangos.examples.mergers as mergers
redshift, ratio, progenitor_halos = mergers.get_mergers_of_major_progenitor(halo)
# each item of progenitor_halos is a pair; the first is the major progenitor, the second is the thing merging into it
merging_structures = [x[1] for x in progenitor_halos] 
print("There are %d mergers into the major progenitor branch." % len(merging_structures))

for i, merging_halo in enumerate(merging_structures):
    print("Merging halo %d: %s/%s" % (i, merging_halo, len(merging_structures)))
    # print(merging_halo.keys())
    # print("  Mass: %f" % merging_halo['Mvir'])
    print("  Redshift: %f" % redshift[i])
    print("  Ratio: %f" % ratio[i])
    print("  Progenitor halo: %s" % progenitor_halos[i][0])
    print()
# Out:
# There are 10 mergers into the major progenitor branch.
# Merging halo 0: <Halo 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.002048/halo_35' | NDM=44650 Nstar=0 Ngas=0>/10
#   Redshift: 0.749969
#   Ratio: 45.563740
#   Progenitor halo: <Halo 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.002048/halo_1' | NDM=2034421 Nstar=163833 Ngas=346127>
#
# Merging halo 1: <Halo 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000672/halo_91' | NDM=10307 Nstar=0 Ngas=4>/10
#   Redshift: 2.652862
#   Ratio: 80.366450
#   Progenitor halo: <Halo 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000672/halo_1' | NDM=828337 Nstar=110643 Ngas=372171>
#
# Merging halo 2: <Halo 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000512/halo_14' | NDM=41291 Nstar=0 Ngas=15088>/10
#   Redshift: 3.131475
#   Ratio: 16.594197
#   Progenitor halo: <Halo 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000512/halo_1' | NDM=685191 Nstar=88821 Ngas=311008>
#
# Merging halo 3: <Halo 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000384/halo_9' | NDM=74503 Nstar=7531 Ngas=58044>/10
#   Redshift: 3.996057
#   Ratio: 1.609734
#   Progenitor halo: <Halo 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000384/halo_4' | NDM=119930 Nstar=1372 Ngas=105353>
#
# Merging halo 4: <Halo 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000384/halo_8' | NDM=78020 Nstar=2454 Ngas=66317>/10
#   Redshift: 3.996057
#   Ratio: 1.537170
#   Progenitor halo: <Halo 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000384/halo_4' | NDM=119930 Nstar=1372 Ngas=105353>
#
# Merging halo 5: <Halo 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000384/halo_14' | NDM=23121 Nstar=233 Ngas=34652>/10
#   Redshift: 3.996057
#   Ratio: 5.187059
#   Progenitor halo: <Halo 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000384/halo_4' | NDM=119930 Nstar=1372 Ngas=105353>
#
# Merging halo 6: <Halo 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000384/halo_18' | NDM=28697 Nstar=0 Ngas=12730>/10
#   Redshift: 3.996057
#   Ratio: 4.179182
#   Progenitor halo: <Halo 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000384/halo_4' | NDM=119930 Nstar=1372 Ngas=105353>
#
# Merging halo 7: <Halo 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000384/halo_78' | NDM=7811 Nstar=0 Ngas=0>/10
#   Redshift: 3.996057
#   Ratio: 15.353988
#   Progenitor halo: <Halo 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000384/halo_4' | NDM=119930 Nstar=1372 Ngas=105353>
#
# Merging halo 8: <Halo 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000384/halo_201' | NDM=2671 Nstar=0 Ngas=0>/10
#   Redshift: 3.996057
#   Ratio: 44.900786
#   Progenitor halo: <Halo 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000384/halo_4' | NDM=119930 Nstar=1372 Ngas=105353>
#
# Merging halo 9: <Halo 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000384/halo_206' | NDM=2614 Nstar=0 Ngas=0>/10
#   Redshift: 3.996057
#   Ratio: 45.879878
#   Progenitor halo: <Halo 'cptmarvel.4096g5HbwK1BH_bn/cptmarvel.cosmo25cmb.4096g5HbwK1BH.000384/halo_4' | NDM=119930 Nstar=1372 Ngas=105353>

# %%
# now here are your properties:

mass_max_tangos_object = [m.calculate('find_progenitor(Mvir, "max")') for m in merging_structures[1:]]

# %%
max_mass = [m['Mvir'] for m in mass_max_tangos_object]
mass_at_infall = [m['Mvir'] for m in merging_structures]
time_of_accretion = [m.timestep.time_gyr for m in merging_structures]
time_max_mass = [m.timestep.time_gyr for m in mass_max_tangos_object]
halo_numbers = [m.calculate_for_progenitors('halo_number()') for m in merging_structures]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 2
#       1 max_mass = [m['Mvir'] for m in mass_max_tangos_object]
# ----> 2 mass_at_infall = [m['Mvir'] for m in merging_structures]
#       3 time_of_accretion = [m.timestep.time_gyr for m in merging_structures]
#       4 time_max_mass = [m.timestep.time_gyr for m in mass_max_tangos_object]
#
# Cell In[26], line 2, in <listcomp>(.0)
#       1 max_mass = [m['Mvir'] for m in mass_max_tangos_object]
# ----> 2 mass_at_infall = [m['Mvir'] for m in merging_structures]
#       3 time_of_accretion = [m.timestep.time_gyr for m in merging_structures]
#       4 time_max_mass = [m.timestep.time_gyr for m in mass_max_tangos_object]
#
# File ~/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/tangos/core/halo.py:194, in SimulationObjectBase.__getitem__(self, key)
#     192 def __getitem__(self, key):
#     193     """Highest-level method for retrieving data or link"""
# --> 194     return self.get_data(key)
#
# File ~/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/tangos/core/halo.py:219, in SimulationObjectBase.get_data(self, key, raw, always_return_array)
#     216     getters=[extraction_patterns.HaloPropertyValueGetter()]
#     217 getters+=[extraction_patterns.HaloLinkTargetGetter()]
# --> 219 return_data = self.get_objects(key, getters)
#     221 if (not always_return_array) and len(return_data) == 1:
#     222     return_data = return_data[0]
#
# File ~/anaconda3/envs/conda-env-py311/lib/python3.11/site-packages/tangos/core/halo.py:243, in SimulationObjectBase.get_objects(self, key, getters)
#     240     ret_values += g.get(self, key_id, session)
#     242 if len(ret_values) == 0:
# --> 243     raise KeyError("No such property %r" % key)
#     244 return ret_values
#
# KeyError: "No such property 'Mvir'"
